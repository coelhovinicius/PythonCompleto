# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Alo mundo!')
# Out:
# Alo mundo!

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = float(input('Digite um número: '))
print(f'O número informado foi {numero}')
# Out:
# O número informado foi 2.0

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 = float(input('Digite um número: '))
numero2 = float(input('Digite outro número: '))
# soma = numero1 + numero2

print(f'Primeiro número informado: {numero1}')
print(f'Segundo número informado: {numero2}')
print(f'A soma dos números é {numero1 + numero2}')
# print(f'A soma dos números é {soma}')
# Out:
# Primeiro número informado: 2.0
# Segundo número informado: 2.0
# A soma dos números é 4.0

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = float(input('Informe a nota do 1º bimestre: '))
nota2 = float(input('Informe a nota do 2º bimestre: '))
nota3 = float(input('Informe a nota do 3º bimestre: '))
nota4 = float(input('Informe a nota do 4º bimestre: '))

media = (nota1 + nota2 + nota3 + nota4) / 4

print(f'1º Bimestre: {nota1}')
print(f'2º Bimestre: {nota2}')
print(f'3º Bimestre: {nota3}')
print(f'4º Bimestre: {nota4}')
# print('')
print(f'Média: {media}')
# Out:
# 1º Bimestre: 9.0
# 2º Bimestre: 9.5
# 3º Bimestre: 9.0
# 4º Bimestre: 8.5
# Média: 9.0

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
numero = float(input('Digite um número em metros para transformar em centímetros: '))

print(f'Número digitado: {numero}')
print(f'{numero}m = {numero * 100}cm')
# Out:
# Número digitado: 10.0
# 10.0m = 1000.0cm

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input('Digite a largura em metros: '))
comprimento = float(input('Digite o comprimento em metros: '))

print(f'Largura: {largura}')
print(f'Comprimento: {comprimento}')
print(f'Área: {largura * comprimento}m2')
# Out:
# Largura: 5.0
# Comprimento: 4.0
# Área: 20.0m2

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
salario_hora = float(input('Digite o salário por hora: '))
horas_trabalhadas = float(input('Digite o número de horas trabalhadas: '))

print(f'Salário por hora: {salario_hora}')
print(f'Horas trabalhadas: {horas_trabalhadas}')
print(f'Salário Total: R${salario_hora * horas_trabalhadas}')
# Out:
# Salário por hora: 200.0
# Horas trabalhadas: 44.0
# Salário Total: R$8800.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
temperatura_fahrenheit = float(input('Digite a temperatura em graus Fahrenheit: '))
celcius = (temperatura_fahrenheit - 32) * (5 / 9)

print(f'Temperatura informada: {temperatura_fahrenheit}°F')
print (f'Temperatura em graus Celcius: {celcius}°C')
# Out:
# Temperatura informada: 70.0°F
# Temperatura em graus Celcius: 21.11111111111111°C

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
temperatura_celcius = float(input('Digite a temperatura em graus Celcius: '))

fahrenheit = temperatura_celcius * 9 / 5 + 32

print(f'Temperatura informada: {temperatura_celcius}°C')
print (f'Temperatura em graus Fahrenheit: {fahrenheit}°F')
# Out:
# Temperatura informada: 20.0°C
# Temperatura em graus Fahrenheit: 68.0°F

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Digite sua altura em metros: '))

peso_ideal = 72.2 * altura - 58

print(f'Altura: {altura}m')
print(f'Seu peso ideal é {peso_ideal}Kg')
# Out:
# Altura: 1.68m
# Seu peso ideal é 63.29600000000001Kg

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input('Digite sua altura em metros: '))

peso_ideal_homem = 72.2 * altura - 58
peso_ideal_mulher = 62.1 * altura - 44.7

print(f'Altura: {altura}m')
print(f'Peso ideal para Homens: {peso_ideal_homem}Kg')
print(f'Peso ideal para Mulheres: {peso_ideal_mulher}Kg')
# Out:
# Altura: 1.49m
# Peso ideal para Homens: 49.578Kg
# Peso ideal para Mulheres: 47.82899999999999Kg

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
salario_hora = float(input('Informe seu salário:'))
horas_trabalhadas = float(input('Informe o número de horas trabalhadas: '))

print(f'Salário por hora: R${salario_hora}')
print(f'Horas trabalhadas: {horas_trabalhadas} horas')
# Out:
# Salário por hora: R$200.0
# Horas trabalhadas: 40.0 horas

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = salario_hora * horas_trabalhadas
print(f'Salário bruto: R${salario_bruto}')
# Out:
# Salário bruto: R$8000.0

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desconto_ir = salario_bruto * 0.11
print(f'Imposto de Renda: R${desconto_ir}')
# Out:
# Imposto de Renda: R$880.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desconto_inss = salario_bruto * 0.08
print(f'INSS: R${desconto_inss}')
# Out:
# INSS: R$640.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desconto_sindical = salario_bruto * 0.05
print(f'Imposto Sindical: R${desconto_sindical}')
# Out:
# Imposto Sindical: R$400.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - desconto_inss - desconto_ir - desconto_sindical
print(f'Salário líquido: R${salario_liquido}')
# Out:
# Salário líquido: R$6080.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = float(input('Informe a área a ser pintada, em metros quadrados: '))

latas = area / 3 / 18
valor_total = latas * 80

print(f'Área a ser pintada: {area}m2')
print(f'Latas necessárias: {latas} latas')
print(f'Valor total: R${valor_total}')
# Out:
# Área a ser pintada: 25.0m2
# Latas necessárias: 0.462962962962963 latas
# Valor total: R$37.03703703703704

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho_arquivo = float(input('Digite o tamanho do arquivo (em MB): '))
velocidade_link = float(input('Digite a velocidade do link (em Mbps): '))

tempo_download = tamanho_arquivo / velocidade_link * 8 / 60

print(f'Tamanho do arquivo: {tamanho_arquivo}MB')
print(f'Velocidade do link: {velocidade_link}Mbps')
print(f'Tempo estimado de download: {tempo_download} minutos')
# Out:
# Tamanho do arquivo: 2000.0MB
# Velocidade do link: 60.0Mbps
# Tempo estimado de download: 4.444444444444445 minutos
