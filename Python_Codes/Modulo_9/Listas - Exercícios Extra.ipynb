# %% [markdown]
# # Listas
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que leia as vendas dos vendedores, mostre a venda de cada vendedor com o seu nome e a média de vendas.

# %%
vendas = [1000, 1500, 1200, 1300]
vendedores = ["Vinícius", "Juliane", "Ciclano", "Cida"]

for i, venda in enumerate(vendas):
    print('{} vendeu {} produtos'.format(vendedores[i], vendas[i]))

#print(sum(vendas))
print('A média de vendas foi de {:.0f} produtos'.format(sum(vendas) / len(vendas)))
print('A média de vendas foi de {:.0f} produtos'.format(sum(vendas) / (i + 1)))
# Out:
# Vinícius vendeu 1000 produtos
# Juliane vendeu 1500 produtos
# Ciclano vendeu 1200 produtos
# Cida vendeu 1300 produtos
# A média de vendas foi de 1250 produtos
# A média de vendas foi de 1250 produtos

# %% [markdown]
# #### 2. Faça um Programa que crie uma lista com as médias de cada aluno, imprima as médias de cada aluno e a quantidade de alunos com média maior que 7.

# %%
alunos = ["José", "Joana", "Maria", "Carla", "Mauricio", "Andre", "Tiago", "Enzo", "Amanda", "Alessandra"]
notas = [
    [10, 9, 8, 8],
    [9, 7, 6, 4],
    [10, 10, 10, 10],
    [5, 3, 10, 9],
    [7, 6, 6, 6],
    [7, 7, 8, 7],
    [7, 7, 7, 9],
    [8, 5, 6, 7],
    [10, 9, 7, 4],
    [10, 1, 3, 3],
]

medias = []
for i in range(len(notas)):
    media = sum(notas[i]) / len(notas[i])
    medias.append(media)
    print('{}: Média = {}'.format(alunos[i], medias[i]))
    #print(alunos[i], '-', 'Média = {}'.format(media))

contador = 0
for media in medias:
    if media >= 7:
        contador += 1
        
print('{} alunos tiveram nota maior ou igual a 7'.format(contador))
# Out:
# José: Média = 8.75
# Joana: Média = 6.5
# Maria: Média = 10.0
# Carla: Média = 6.75
# Mauricio: Média = 6.25
# Andre: Média = 7.25
# Tiago: Média = 7.5
# Enzo: Média = 6.5
# Amanda: Média = 7.5
# Alessandra: Média = 4.25
# 5 alunos tiveram nota maior ou igual a 7

# %% [markdown]
# #### 3. Foram anotadas as idades e salários de 30 funcionários. Faça um programa que determine quantos funcionários com mais de 25 anos possuem salário inferior à média de todos os salários.

# %%
idades = [35,32,50,33,48,50,33,48,22,49,35,38,20,47,49,48,34,21,48,44,48,30,25,42,42,23,25,23,38,35]
salarios = [3739,2219,3554,3978,4014,3270,4792,3879,2981,2384,4826,2460,3680,4318,1872,1770,4640,3929,3295,1729,3965,4267,4007,1916,2987,2943,3852,4543,2055,1730]

media_salarial = sum(salarios) / len(salarios)
print('Média salarial:', media_salarial)

contador = 0
for i, idade in enumerate(idades):
    if idade > 25 and salarios[i] < media_salarial:
        contador += 1

print('{} funcionários com mais de 25 anos recebem salário menor que a média de R${:,.2f}'.format(contador, media_salarial))
# Out:
# Média salarial: 3319.8
# 12 funcionários com mais de 25 anos recebem salário menor que a média de R$3,319.80

# %% [markdown]
# #### 4.Em quais meses a média de temperatura foi maior do que a média nacional?

# %%
meses = [
    'Janeiro',
    'Fevereiro',
    'Março',
    'Abril',
    'Maio',
    'Junho',
    'Julho',
    'Agosto',
    'Setembro',
    'Outubro',
    'Novembro',
    'Dezembro'
]

temperaturas = [30, 29, 28, 28, 25, 26, 20, 21, 19, 25, 27, 32]

media_temperaturas = sum(temperaturas) / len(temperaturas)
print('Média de temperatura nacional anual: {:.1f}°C'.format(media_temperaturas))

for i, mes in enumerate(meses):
    if temperaturas[i] > media_temperaturas:
        print('{}: {:.1f}°C'.format(meses[i], temperaturas[i]))
# Out:
# Média de temperatura nacional anual: 25.8°C
# Janeiro: 30.0°C
# Fevereiro: 29.0°C
# Março: 28.0°C
# Abril: 28.0°C
# Junho: 26.0°C
# Novembro: 27.0°C
# Dezembro: 32.0°C

# %% [markdown]
# #### 5. As Organizações Tabajara resolveram dar um abono aos seus colaboradores em reconhecimento ao bom resultado alcançado durante o ano que passou. Para isto, contratou você para desenvolver a aplicação que servirá como uma projeção de quanto será gasto com o pagamento deste abono.
# <pre>Após reuniões envolvendo a diretoria executiva, a diretoria financeira e os representantes do sindicato laboral, chegou-se a seguinte forma de cálculo:
# . Cada funcionário receberá o equivalente a 20% do seu salário bruto de dezembro;
# . O piso do abono será de 100 reais, isto é, aqueles funcionários cujo salário for muito baixo, recebem este valor mínimo;
#
# Neste momento, não se deve ter nenhuma preocupação com colaboradores com tempo menor de casa, descontos, impostos ou outras particularidades.
# O programa deverá calcular o valor do abono concedido a cada colaborador, de acordo com a regra definida acima. Ao final, o programa deverá apresentar:</pre>
# <pre>
# O salário de cada funcionário, juntamente com o valor do abono;
# O número total de funcionário processados;
# O valor total a ser gasto com o pagamento do abono;
# O número de funcionário que receberá o valor mínimo de 100 reais;
# O maior valor pago como abono;
#
# A tela abaixo é um exemplo de execução do programa, apenas para fins ilustrativos.
# <pre>
#
# Projeção de Gastos com Abono
# ============================
#
# Salário: 1000
# Salário: 300
# Salário: 500
# Salário: 100
# Salário: 4500
# Salário: 0
#
# Salário    - Abono
# R$ 1000.00 - R$  200.00
# R$  300.00 - R$  100.00
# R$  500.00 - R$  100.00
# R$  100.00 - R$  100.00
# R$ 4500.00 - R$  900.00
#
# Foram processados 5 colaboradores
# Total gasto com abonos: R$ 1400.00
# Valor mínimo pago a 3 colaboradores
# Maior valor de abono pago: R$ 900.00

# %%
lista_salarios = [1000, 300, 500, 200, 1500, 3000, 3400, 5000, 7000, 2000, 600, 800, 250, 1500, 20000]
abonos = []

print('Projeção de Gastos com Abono')
print('============================')
print('')

'''
for i in lista_salarios:
    print('Salário: R${:,.2f}'.format(i))

print('')'''

print('Salários - Abono')

contador_min = 0 # Inicia o contador de colaboradores
for salario in lista_salarios:
    abono = salario * 0.2
    if abono < 100:
        abono = 100
    
    abonos.append(abono)

    if abono == 100:
        contador_min += 1

    print('R${:,.2f} - R${:,.2f}'.format(salario, abono))

qtde = len(lista_salarios)
total = sum(abonos)
maximo = max(abonos)

print('')
print('Foram calculados abonos de {} colaboradores'.format(qtde))
print('Total gasto com abonos: R${:,.2f}'.format(total))
print('O maior abono foi de R${:,.2f}'.format(maximo))
# Out:
# Projeção de Gastos com Abono
# ============================
#
# Salários - Abono
# R$1,000.00 - R$200.00
# R$300.00 - R$100.00
# R$500.00 - R$100.00
# R$200.00 - R$100.00
# R$1,500.00 - R$300.00
# R$3,000.00 - R$600.00
# R$3,400.00 - R$680.00
# R$5,000.00 - R$1,000.00
# R$7,000.00 - R$1,400.00
# R$2,000.00 - R$400.00
# R$600.00 - R$120.00
# R$800.00 - R$160.00
# R$250.00 - R$100.00
# R$1,500.00 - R$300.00
# R$20,000.00 - R$4,000.00
#
# Foram calculados abonos de 15 colaboradores
# Total gasto com abonos: R$9,560.00
# O maior abono foi de R$4,000.00

# %% [markdown]
# #### 6. Faça um programa que carregue uma lista com os modelos de cinco carros (exemplo de modelos: FUSCA, GOL, VECTRA etc). Carregue uma outra lista com o consumo desses carros, isto é, quantos quilômetros cada um desses carros faz com um litro de combustível. Calcule e mostre:
# <pre>
# a. O modelo do carro mais econômico;
# b. Quantos litros de combustível cada um dos carros cadastrados consome para percorrer uma distância de 1000 quilômetros e quanto isto custará, considerando um cenário em que a gasolina custe R$ 2,25 o litro. Abaixo segue uma tela de exemplo. A disposição das informações deve ser o mais próxima possível ao exemplo. Os dados são fictícios e podem mudar a cada execução do programa.</pre>
# ```
# Comparativo de Consumo de Combustível
#
# Veículo 1
# Nome: fusca
# Km por litro: 7
# Veículo 2
# Nome: gol
# Km por litro: 10
# Veículo 3
# Nome: uno
# Km por litro: 12.5
# Veículo 4
# Nome: Vectra
# Km por litro: 9
# Veículo 5
# Nome: Peugeout
# Km por litro: 14.5
#
# Relatório Final
#  1 - fusca           -    7.0 -  142.9 litros - R$ 321.43
#  2 - gol             -   10.0 -  100.0 litros - R$ 225.00
#  3 - uno             -   12.5 -   80.0 litros - R$ 180.00
#  4 - vectra          -    9.0 -  111.1 litros - R$ 250.00
#  5 - peugeout        -   14.5 -   69.0 litros - R$ 155.17
# O menor consumo é do peugeout.
# ```

# %%
veiculos = ['fusca','gol', 'uno', 'vectra', 'march']
autonomias = [7, 10, 12.5, 9, 14.5]
gasolina = 2.25

print('Comparativo de Consumo de Combustível')
print('')

for i, veiculo in enumerate(veiculos):
    print('Veículo', i + 1)
    print(veiculo.capitalize())
    print('Km por litro:', autonomias[i])

print('')
print('Relatório Final')

for i, autonomia in enumerate(autonomias):
    print('{} - {} - {:.1f} - {:.1f} litros - R${:,.2f}'.format(i + 1, veiculos[i].capitalize(), autonomia, 1000 / autonomia, 1000 / autonomia * gasolina))
    #print(f'{i+1} - {veiculos[i]} - {autonomia:.1f} - {1000/autonomia:.2f} - R$ {1000/autonomia* gasolina:.2f}')
    
melhor = max(autonomias)
i = autonomias.index(melhor)
print('')
print('O menor consumo é do', veiculos[i].capitalize())
# Out:
# Comparativo de Consumo de Combustível
#
# Veículo 1
# Fusca
# Km por litro: 7
# Veículo 2
# Gol
# Km por litro: 10
# Veículo 3
# Uno
# Km por litro: 12.5
# Veículo 4
# Vectra
# Km por litro: 9
# Veículo 5
# March
# Km por litro: 14.5
#
# Relatório Final
# 1 - Fusca - 7.0 - 142.9 litros - R$321.43
# 2 - Gol - 10.0 - 100.0 litros - R$225.00
# 3 - Uno - 12.5 - 80.0 litros - R$180.00
# 4 - Vectra - 9.0 - 111.1 litros - R$250.00
# 5 - March - 14.5 - 69.0 litros - R$155.17
#
# O menor consumo é do March

# %% [markdown]
# #### 7. Uma empresa paga seus vendedores com base em comissões. O vendedor recebe \\$200 por semana mais 9 por cento de suas vendas brutas daquela semana. Por exemplo, um vendedor que teve vendas brutas de \\$3000 em uma semana recebe \\$200 mais 9 por cento de \\$3000, ou seja, um total de \\$470. Escreva um programa (usando um array de contadores) que determine quantos vendedores receberam salários nos seguintes intervalos de valores:
# <pre>
# $200 - $299
# $300 - $399
# $400 - $499
# $500 - $599
# $600 - $699
# $700 - $799
# $800 - $899
# $900 - $999
# $1000 em diante
# </pre>
#
# Existem várias formas de fazer. Faça primeiro da forma que parecer mais intuitiva para você.
#
# Em seguida, caso queira um desafio:
# Desafio: Crie uma forma para chegar na posição da lista a partir do salário, sem fazer vários ifs aninhados.

# %%
vendas = [1000, 2000, 3000, 4000, 5000, 6000, 5500, 4500, 3600]
faixas = []
menores_que_mil = 0
tamanho_faixas = 100
qtde_faixas = 9

for venda in vendas:
    bonus = venda * 0.09
    salario = 200 + bonus
    faixa = int(bonus / tamanho_faixas) + 1
    faixas.append(faixa)

for i in range(qtde_faixas - 1):
    print('Entre R${:,.2f} e R${:,.2f}: {} vendedores'.format(i * 100 + 200, i * 100 + 299, faixas.count(i + 1)))
    menores_que_mil += faixas.count(i + 1)

print('Mais que R$1,000.00: {} vendedores'.format(len(vendas) - menores_que_mil))
# Out:
# Entre R$200.00 e R$299.00: 1 vendedores
# Entre R$300.00 e R$399.00: 1 vendedores
# Entre R$400.00 e R$499.00: 1 vendedores
# Entre R$500.00 e R$599.00: 2 vendedores
# Entre R$600.00 e R$699.00: 3 vendedores
# Entre R$700.00 e R$799.00: 1 vendedores
# Entre R$800.00 e R$899.00: 0 vendedores
# Entre R$900.00 e R$999.00: 0 vendedores
# Mais que R$1,000.00: 0 vendedores
