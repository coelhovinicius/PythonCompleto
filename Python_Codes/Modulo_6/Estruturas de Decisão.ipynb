# %% [markdown]
# # Estruturas de decisão
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que peça dois números e imprima o maior deles.

# %%
a = input('Digite um número: ')
b = input('Digite outro número: ')

if a and b:
    if a > b:
        print('O maior número é o {}'.format(a))
    elif a < b:
        print('O maior número é o {}'.format(b))
    else:
        print('Os números são iguais.')
else:
    print('Dados inválidos. Favor preencher corretamente.')
# Out:
# Os números são iguais.

# %% [markdown]
# #### 2. Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
a = input('Digite um número: ')

if a:
    a = int(a)
    if a >= 0:
        print("O número {} é positivo.".format(a))
    else:
        print("O número {} é negativo.".format(a))
else:
    print('Digite um número válido.')
# Out:
# O número 8 é positivo.

# %% [markdown]
# #### 3. Faça um Programa que verifique o estado civil de uma pessoa. Se a letra digitada é "C" (Casado), "S" (Solteiro), "D" (Divorciado), "V" (Viúvo) ou "O" (outros). Conforme a letra escrita pelo usuário seu programa deve escrever o estado civil, exemplo:
#
# Usuário digita: C
#
# Seu programa deve responder:
# C - Casado

# %%
estado_civil = input('Digite seu estado civil (C para Casado, S para Solteiro, D para Divorciado, V para Viúvo, O para Outros)')

if estado_civil:
    if estado_civil.upper() == 'C':
        print ('{} - Casado'.format(estado_civil.upper()))
    elif estado_civil.upper() == 'S':
        print ('{} - Solteiro'.format(estado_civil.upper()))
    elif estado_civil.upper() == 'D':
        print ('{} - Divorciado'.format(estado_civil.upper()))
    elif estado_civil.upper() == 'V':
        print ('{} - Viúvo'.format(estado_civil.upper()))  
    else:
        print ('{} - Outros'.format(estado_civil.upper()))
else:
    print('Preenchimento incorreto.')
# Out:
# 9 - Outros

# %% [markdown]
# #### 4. Faça um Programa que verifique se o e-mail digitado faz parte dos e-mails de spam.

# %%
emails_spam = "fulano@gmail.com,beltrano@gmail.com,ciclano@gmail.com"

email = input('Digite o e-mail: ')

if email and ('@' in email):
    if email in emails_spam:
        print('SPAM! E-mail {} reportado como Spam!'.format(email))
    else:
        print('O e-mail {} é válido.'.format(email))
else:
    print('Favor preencher o campo corretamente.')
# Out:
# O e-mail vinicius@gmail.com é válido.

# %% [markdown]
# #### 5. Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
#
# ##### A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### A mensagem "Reprovado", se a média for menor do que sete;
# ##### A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = input('Digite a primeira nota: ')
nota2 = input('Digite a segunda nota: ')

if nota1 and nota2:
    media = (float(nota1) + float(nota2)) / 2
    if media >= 10:
        print('Aprovado com Distinção!')
    elif media >= 7:
        print('Aprovado')
    else:
        print('Reprovado.')
else:
    print('Nota digitada incorretamente')
# Out:
# Reprovado.

# %% [markdown]
# #### 6. Faça um Programa que leia o orçamento de 3 empresas e mostre o maior deles.

# %%
e1 = input('Informe o orçamento da Empresa 1: ')
e2 = input('Informe o orçamento da Empresa 2: ')
e3 = input('Informe o orçamento da Empresa 3: ')

if e1 and e2 and e3:
    e1 = float(e1)
    e2 = float(e2)
    e3 = float(e3)
    
    if e1 == e2 and e1 == e3:
        print('Todas as empresas tiveram o mesmo orçamento de R${} cada.'.format(e1))
    elif e1 > e2 and e1 > e3:
        print('A Empresa 1 possui o maior orçamento: R${}.'.format(e1))
    elif e1 > e2 and e1 == e3:
        print('As Empresas 1 e 3 possuem os maiores orçamentos: R${} cada.'.format(e1))
    elif e1 == e2 and e1 > e3:
        print('As Empresas 1 e 2 posuem os maiores orçamentos: R${} cada.'.format(e1))
    elif e2 > e3:
        print('A Empresa 2 possui o maior orçamento: R${}.'.format(e2))
    elif e2 == e3:
        print('As Empresas 2 e 3 possuem os maiores orçamentos: R${} cada.'.format(e2))
    else:
        print ('A Empresa 3 possui o maior orçamento: R${}.'.format(e3))
else:
    print('Os campos foram preenchidos incorretamente.')
# Out:
# A Empresa 2 possui o maior orçamento: R$50000.0.

# %% [markdown]
# #### 7. Faça um Programa que leia três orçamentos e mostre o maior e o menor deles.

# %%
e1 = input('Informe o orçamento da Empresa 1: ')
e2 = input('Informe o orçamento da Empresa 2: ')
e3 = input('Informe o orçamento da Empresa 3: ')

if e1 and e2 and e3:
    e1 = float(e1)
    e2 = float(e2)
    e3 = float(e3)

    if e1 == e2 == e3:
        print('Todas as empresas tiveram o mesmo orçamento de R${} cada.'.format(e1))
    elif e1 == e2 and e1 > e3:
        print('As empresas 1 e 2 tiveram os maiores orçamentos: R${} cada. A empresa 3 teve o menor orçamento: R${}.'.format(e1, e3))
    elif e1 == e2 and e1 < e3:
        print('A empresa 3 teve o maior orçamento: R${}. As empresas 1 e 2 tiveram os menores orçamentos: R${} cada.'.format(e3, e1)) 
    elif e1 == e3 and e1 > e2:
        print('As empresas 1 e 3 tiveram os maiores orçamentos.: R${} cada. A empresa 2 teve o menor orçamento: R${}.'.format(e1, e2))   
    elif e1 == e3 and e1 < e2:
        print('A empresa 2 teve o maior orçamento: R${}. As empresas 1 e 3 tiveram os menores orçamentos: R${} cada.'.format(e2, e1))
    elif e1 > e2 and e2 > e3:
        print('A empresa 1 teve o maior orçamento: R${}. A empresa 3 teve o menor orçamento: R${}.'.format(e1, e3))         
    elif e1 > e3 and e3 > e2:
        print('A empresa 1 teve o maior orçamento: R${}. A empresa 2 teve o menor orçamento: R${}.'.format(e1, e2))
    elif e2 == e3 and e2 > e1:
        print('As empresas 2 e 3 tiveram o maior orçamento: R${} cada. A empresa 1 teve o menor orçamento: R${}.'.format(e2, e1))
    elif e2 == e3 and e2 < e1:
        print('A empresa 1 teve o maior orçamento: R${}. As empresas 2 e 3 tiveram os menores orçamentos: R${} cada.'.format(e1, e2))
    elif e2 > e1 and e1 > e3:
        print('A empresa 2 teve o maior orçamento: R${}. A empresa 3 teve o menor orçamento: R${}.'.format(e2, e3))
    elif e2 > e3 and e3 > e1:
        print('A empresa 2 teve o maior orçamento: R${}. A empresa 1 teve o menor orçamento: R${}.'.format(e2, e1))
    elif e3 > e1 and e1 > e2:
        print('A empresa 3 teve o maior orçamento: R${}. A empresa 2 teve o menor orçamento: R${}'.format(e3, e2))
    #elif e3 > e2 and e2 > e1:
    else:
        print('A empresa 3 teve o maior orçamento: R${}. A empresa 1 teve o menor orçamento: R${}'.format(e3, e1))
else:
    print('Preencha os campos corretamente.')
# Out:
# A empresa 3 teve o maior orçamento: R$3.0. A empresa 1 teve o menor orçamento: R$1.0

# %% [markdown]
# #### 8. Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
prod1 = input('Digite o valor do Produto 1: ')
prod2 = input('Digite o valor do Produto 2: ')
prod3 = input('Digite o valor do Produto 3: ')

if prod1 and prod2 and prod3:
    prod1 = float(prod1)
    prod2 = float(prod2)
    prod3 = float(prod3)

    if prod1 == prod2 == prod3:
        print('Os três produtos possuem valores iguais.')

    elif (prod2 == prod3 and prod2 > prod1) or (prod2 > prod3 and prod3 > prod1):
        print('Comprar o Produto 1.')

    elif prod1 == prod2 and prod1 < prod3:
        print('Comprar o Produto 1 ou o Produto 2.')

    elif prod1 == prod3 and prod1 < prod2:
        print('Comprar o Produto 1 ou o Produto 3.')

    elif (prod1 == prod3 and prod1 > prod2) or (prod1 > prod3 and prod3 > prod2) or (prod3 > prod1 and prod1 > prod2):
        print('Comprar o Produto 2.')
    
    elif prod2 == prod3 and prod2 < prod1:
        print('Comprar o Produto 2 ou o Produto 3.')

    elif (prod1 == prod2 and prod1 > prod3) or (prod1 > prod2 and prod2 > prod3) or (prod2 > prod1 and prod1 > prod3):
        print('Comprar o Produto 3.')

    else:
        print('Comprar o Produto 1.')

else:
    print('Preencha os campos corretamente.')
# Out:
# Preencha os campos corretamente.

# %% [markdown]
# #### 9. Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
while True:
    try:
        n1 = float(input('Digite o primeiro número: '))
        n2 = float(input('Digite o segundo número: '))
        n3 = float(input('Digite o terceiro número: '))
        break
    except ValueError:
        print('Digite o número corretamente.')

if n1 and n2 and n3:

    numeros = [n1, n2, n3]
    numeros.sort(reverse=True)

    print('Números em ordem decrescente: ', numeros)

else:
    print('Preencha os campos corretamente.')
# Out:
# Números em ordem decrescente:  [50.0, 21.0, 5.0]

# %% [markdown]
# #### 10. Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
turno = input('Informe o turno em que você estuda (M-matutino, V-vespertino ou N-noturno)')

if turno:
    if turno.upper() == 'M':
        print ('Bom dia!')
    elif turno.upper() == 'V':
        print ('Boa tarde!')  
    elif turno.upper() == 'N':
        print ('Boa noite!')
    else:
        print('Preenchimento incorreto.')
else:
    print('Preenchimento incorreto.')
# Out:
# Boa noite!

# %% [markdown]
# #### 11. As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contrataram para desenvolver o programa que calculará os reajustes. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
#
# ##### salários até R\\$ 280,00 (incluindo) : aumento de 20%
#
# ##### salários entre R\\$ 280,00 e R\\$ 700,00 : aumento de 15%
#
# ##### salários entre R\\$ 700,00 e R\\$ 1500,00 : aumento de 10%
#
# ##### salários de R\\$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# ###### o salário antes do reajuste;
#
# ###### o percentual de aumento aplicado;
#
# ###### o valor do aumento;
#
# ###### o novo salário, após o aumento.
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
def imprimir_salario(salario, indice):
    print('Salário antes do reajuste: R${}.'.format(salario))
    print('Percentual de aumento aplicado: {}%.'.format(indice * 100))
    print('Valor do aumento: R${}.'.format(salario * indice))
    print('Novo salário após o aumento: R${}.'.format(salario * (1 + indice)))

while True:
    try:
        salario_bruto = float(input('Digite o salário: '))
        break
    except ValueError:
        print('Digite o salário corretamente.')

if salario_bruto:
    if salario_bruto <= 280:
        indice = 0.2
    elif salario_bruto < 700:
        indice = 0.15
    elif salario_bruto < 1500:
        indice = 0.1
    else:
        indice = 0.05
else:
    print('Salário informado incorretamente.')

imprimir_salario(salario_bruto, indice)
# Out:
# Salário antes do reajuste: R$3000.0.
# Percentual de aumento aplicado: 5.0%.
# Valor do aumento: R$150.0.
# Novo salário após o aumento: R$3150.0.

# %% [markdown]
# #### 12 . Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
#
# Desconto do IR:<br>
# Salário Bruto até 900 (inclusive) - isento<br>
# Salário Bruto até 1500 (inclusive) - desconto de 5%<br>
# Salário Bruto até 2500 (inclusive) - desconto de 10%<br>
# Salário Bruto acima de 2500 - desconto de 20%<br>
# Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de horas é 220.
#
# Salário Bruto: (5 * 220)        : R\\$ 1100,00<br>
# (-) IR (5%)                     : R\\$   55,00<br>
# (-) INSS ( 10%)                 : R\\$  110,00<br>
# FGTS (11%)                      : R\\$  121,00<br>
# Total de descontos              : R\\$  165,00<br>
# Salário Liquido                 : R\\$  935,00<br>
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
def calculo_salario(salario, ir, inss, fgts):
    print('Salário bruto: R${:.2f}.'.format(salario))
    print('(-) IR ({}%): R${:.2f}.'.format(ir * 100, salario * ir))
    print('(-) INSS ({}%): R${:.2f}.'.format(inss * 100, salario * inss))
    print('FGTS ({}%): R${:.2f}.'.format(fgts * 100, salario * fgts))
    print('Total de descontos: R${:.2f}.'.format(salario * ir + salario * inss))
    print('Salário Líquido: R${:.2f}.'.format(salario - salario * ir - salario * inss))

while True:
    try:
        horas_trabalhadas = float(input('Informe a quantidade de horas trabalhadas: '))
        salario_hora = float(input('Informe o salário por hora: '))
        break
    except ValueError:
        print('Digite os campos corretamente.')

if horas_trabalhadas and salario_hora:

    salario_bruto = salario_hora * horas_trabalhadas

    if salario_bruto <= 900:
        ir = 0
    elif salario_bruto <= 1500:
        ir = 0.05
    elif salario_bruto <= 2500:
        ir = 0.1
    else:
        ir = 0.2

    inss = 0.1
    fgts = 0.11

    calculo_salario(salario_bruto, ir, inss, fgts)

else:
    print('Dados informados incorretamente.')
# Out:
# Digite os campos corretamente.
# Digite os campos corretamente.
# Digite os campos corretamente.
# Digite os campos corretamente.
# Digite os campos corretamente.
# Digite os campos corretamente.
# Salário bruto: R$3200.00.
# (-) IR (20.0%): R$640.00.
# (-) INSS (10.0%): R$320.00.
# FGTS (11.0%): R$352.00.
# Total de descontos: R$960.00.
# Salário Líquido: R$2240.00.

# %% [markdown]
# #### 13. Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
while True:
    try:
        dia = int(input('Digite um número de 1 a 7: '))
        break
    except ValueError:
        print('Valor incorreto. Favor digitar novamente.')
        
if dia == 1:
    dia_da_semana = 'Domingo'
elif dia == 2:
    dia_da_semana = 'Segunda'
elif dia == 3:
    dia_da_semana = 'Terça'
elif dia == 4:
    dia_da_semana = 'Quarta'
elif dia == 5:
    dia_da_semana = 'Quinta'
elif dia == 6:
    dia_da_semana = 'Sexta'
elif dia == 7:
    dia_da_semana = 'Sábado'
else:
    dia_da_semana = 'Valor inválido'

print('{} - {}'.format(dia, dia_da_semana))
# Out:
# Valor incorreto. Favor digitar novamente.
# Valor incorreto. Favor digitar novamente.
# Valor incorreto. Favor digitar novamente.
# Valor incorreto. Favor digitar novamente.
# 5 - Quinta

# %% [markdown]
# #### 14. Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. Em seguida, mostre qual conceito o aluno teve. A atribuição de conceitos obedece à tabela abaixo:
# <pre>
# Média de Aproveitamento  Conceito
# Entre 9.0 e 10.0        A
# Entre 7.5 e 9.0         B
# Entre 6.0 e 7.5         C
# Entre 4.0 e 6.0         D
# Entre 4.0 e zero        E
# </pre>

# %%
while True:
    try:
        nota1 = float(input('Digite a primeira nota: '))
        nota2 = float(input('Digite a segunda nota: '))
        break
    except ValueError:
        print('Favor preencher as notas corretamente.')

media = (nota1 + nota2) / 2
print('Média: {}.'.format(media))

if 0 <= media < 4:
    conceito = 'E'
elif 4 <= media < 6:
    conceito = 'D'
elif 6 <= media  < 7.5:
    conceito = 'C'
elif 7.5 <= media < 9:
    conceito = 'B'
elif 9 <= media <= 10:
    conceito = 'A'    
else:
    conceito = 'inválido'

print('Conceito {}'.format(conceito))
# Out:
# Favor preencher as notas corretamente.
# Favor preencher as notas corretamente.
# Média: 5.0.
# Conceito D

# %% [markdown]
# #### 15. Você está construindo um calendário para controlar dias de trabalho a pedido do RH. Nessa construção, você vai precisar definir quais anos são bissextos e quais não são, para montar o calendário de forma correta. Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.
# <pre>
# Dica para determinar se um ano é bissexto:
# - São bissextos todos os anos múltiplos de 400, p.ex.: 1600, 2000, 2400, 2800...
# - São bissextos todos os múltiplos de 4, exceto se for múltiplo de 100 mas não de 400,
# p.ex.: 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024, 2028...
# - Não são bissextos todos os demais anos.<br>
# ex1: 2004 é múltiplo de 4, mas não é múltiplo de 100, então é bissexto.
# ex2: 2000 é múltiplo de 4, mas é múltiplo de 100, só que também é multiplo de 400, então é bissexto (porque todo ano múltiplo de 400 é bissexto, independente do resto).
# ex3: 1900 é múltiplo de 4, é múltiplo de 100, mas não é múltiplo de 400, então não é bissexto
#
# </pre>
#
# Dica: lembre que: numero % 4 é o resto da divisão do número por 4, ex: 10 % 3 = 1 (já que 10/3 = 3 e resta 1)

# %%
while True:
    try:
        ano = int(input('Digite o ano: '))
        break
    except ValueError:
        print('Favor preencher o ano corretamente.')

# Verifica se é bissexto
if ano % 4 == 0:
    if ano % 100 != 0 or ano % 400 == 0:
        print('{} é um ano bissexto.'.format(ano))
    else:
        print('O ano {} não é bissexto.'.format(ano))
else:
    print('{} não é um ano bissexto.'.format(ano))
# Out:
# 2024 é um ano bissexto.

# %% [markdown]
# #### 16. Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:
# <pre>
# A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
# A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
# A mensagem "Aprovado com Distinção", se a média for igual a 10.
# </pre>

# %%
while True:
    try:
        nota1 = float(input('Digite a 1ª nota: '))
        nota2 = float(input('Digite a 2ª nota: '))
        nota3 = float(input('Digite a 3ª nota: '))
        break
    except ValueError:
        print('Favor preencher corretamente.')

if nota1 and nota2 and nota3:
    media = (nota1 + nota2 + nota3) / 3
    if media == 10:
        print('Aprovado com Distinção')
    elif media >= 7:
        print('Aprovado.')
    else:
        print('Reprovado')
else:
    print('Favor preencher corretamente')
# Out:
# Reprovado

# %% [markdown]
# #### 17. João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso = 0.0
excesso = 0.0
multa = 0.0
taxa = 4.0
max_kg = 50.0

while True:
    try:
        peso = float(input('Informe o peso dos peixes.'))
        break
    except ValueError:
        print('Digite o peso corretamente.')

if peso:
    if peso > max_kg:
        excesso = peso - max_kg
        multa = excesso * taxa
    else:
        pass
    print('Peso dos peixes: {:.0f}Kg.'.format(peso))
    print('Peso excedente: {:.0f}Kg.'.format(excesso))
    print('Multa por peso excedente: R${:.2f}.'.format(multa))
else:
    print('Preencha corretamente o campo.')
# Out:
# Peso dos peixes: 55Kg.
# Peso excedente: 5Kg.
# Multa por peso excedente: R$20.00.

# %% [markdown]
# #### 18. Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário o valor do saque e depois informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
# <pre>
# Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
# Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.
# </pre>
#
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10.<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10.

# %%
n100 = 0
n50 = 0
n10 = 0
n5 = 0
n1 = 0

while True:
    try:
        valor = int(input('Informe o valor do saque (Mínimo R$10,00 - Máximo R$600,00): '))
        break
    except ValueError:
        print('Digite corretamente o valor do saque.')

if 10 <= valor <= 600:
    print('São necessárias:')
    if valor > 100:
        n100 = valor // 100
        print(n100, 'notas de 100')
    if valor % 100 >= 50:
        n50 = (valor - 100*n100) // 50
        print(n50, 'notas de 50')
    if valor % 50 >= 10:
        n10 = (valor - 100*n100 - 50*n50) // 10
        print(n10, 'notas de 10')
    if valor % 10 >= 5:
        n5 = (valor - 100*n100 - 50*n50 - 10*n10) // 5
        print(n5, 'notas de 5')
    if valor % 5 >= 1:
        n1 = valor - 100*n100 - 50*n50 - 10*n10 - 5*n5
        print(n1, 'notas de 1')
else:
    print('Informe um valor entre 10 e 600 reais')

'''
saque_minimo = 10
saque_maximo = 600

while True:
    try:
        valor_saque = int(input('Informe o valor do saque (Mínimo R$10,00 - Máximo R$600,00): '))
        break
    except ValueError:
        print('Digite corretamente o valor do saque.')

if valor_saque:
    if valor_saque < saque_minimo or valor_saque > saque_maximo:
        print('Valor de saque inválido.')
    else:
        notas = [100, 50, 10, 5, 1]
        quantidades = [0, 0, 0, 0, 0]

        for i, nota in enumerate(notas):
            if valor_saque >= nota:
                quantidades[i] = valor_saque // nota
                valor_saque -= quantidades[i] * nota

        for i in range(len(notas)):
            if quantidades[i] > 0:
                print(f'{quantidades[i]} nota(s) de R${notas[i]}')
else:
    print('Valor de saque inválido.')
'''
# Out:
# São necessárias:
# 5 notas de 100
# 1 notas de 50
# 3 notas de 10
# 3 notas de 1
# "\nsaque_minimo = 10\nsaque_maximo = 600\n\nwhile True:\n    try:\n        valor_saque = int(input('Informe o valor do saque (Mínimo R$10,00 - Máximo R$600,00): '))\n        break\n    except ValueError:\n        print('Digite corretamente o valor do saque.')\n\nif valor_saque:\n    if valor_saque < saque_minimo or valor_saque > saque_maximo:\n        print('Valor de saque inválido.')\n    else:\n        notas = [100, 50, 10, 5, 1]\n        quantidades = [0, 0, 0, 0, 0]\n\n        for i, nota in enumerate(notas):\n            if valor_saque >= nota:\n                quantidades[i] = valor_saque // nota\n                valor_saque -= quantidades[i] * nota\n\n        for i in range(len(notas)):\n            if quantidades[i] > 0:\n                print(f'{quantidades[i]} nota(s) de R${notas[i]}')\nelse:\n    print('Valor de saque inválido.')\n"

# %% [markdown]
# #### 19. Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
# <pre>
# "Telefonou para a vítima?"
# "Esteve no local do crime?"
# "Mora perto da vítima?"
# "Devia para a vítima?"
# "Já trabalhou com a vítima?"
# O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".
# </pre>

# %%
contador = 0

p1 = str(input('Telefonou para a vítima (responder com SIM ou NAO)?'))
p2 = str(input('Esteve no local do crime (responder com SIM ou NAO)?'))
p3 = str(input('Mora perto do local do crime (responder com SIM ou NAO)?'))
p4 = str(input('Devia para a vítima (responder com SIM ou NAO)?'))
p5 = str(input('Já trabalhou com a vítima (responder com SIM ou NAO)?'))

if p1 and p2 and p3 and p4 and p5:
            
    if p1.upper() == 'SIM':
        contador += 1
    if p2.upper() == 'SIM':
        contador += 1
    if p3.upper() == 'SIM':
        contador += 1
    if p4.upper() == 'SIM':
        contador += 1
    if p5.upper() == 'SIM':
        contador += 1
else:
    print('Digite SIM ou NAO.')

if contador == 2:
    print('Suspeito')
elif 3 <= contador <= 4:
    print('Cúmplice')
elif contador == 5:
    print('Culpado')
else:
    print('Inocente')


    '''# Lista de perguntas
perguntas = [
    "Telefonou para a vítima?",
    "Esteve no local do crime?",
    "Mora perto da vítima?",
    "Devia para a vítima?",
    "Já trabalhou com a vítima?"
]

# Contador de respostas positivas
respostas_positivas = 0

# Faz as perguntas
for pergunta in perguntas:
    resposta = input(pergunta + " (s/n): ")
    if resposta.lower() == "s":
        respostas_positivas += 1

# Classifica a participação no crime
if respostas_positivas == 2:
    print("Suspeita")
elif 3 <= respostas_positivas <= 4:
    print("Cúmplice")
elif respostas_positivas == 5:
    print("Assassino")
else:
    print("Inocente")
'''
# Out:
# Digite SIM ou NAO.
# Inocente

# %% [markdown]
# #### 20. Um posto está vendendo combustíveis com a seguinte tabela de descontos:
# <pre>
# Álcool:
# até 20 litros, desconto de 3% por litro
# acima de 20 litros, desconto de 5% por litro
# Gasolina:
# até 20 litros, desconto de 4% por litro
# acima de 20 litros, desconto de 6% por litro
#
# Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da gasolina é R$ 2,50 o preço do litro do álcool é R$ 1,90.
# </pre>

# %%
preco_alcool = 3.4
preco_gasolina = 5.1

while True:
    try:
        tipo_combustivel = str(input('Informe o tipo de combustível (A -Álcool / G -Gasolina): '))
        qtde_litros = float(input('Informe a quantidade em Litros: '))

        break
    except ValueError:
        print('Dados incorretos. Favor informar novamente.')

if tipo_combustivel and qtde_litros:
    if (tipo_combustivel.upper() == 'A') or (tipo_combustivel.upper() == 'G'):
        if tipo_combustivel.upper() == 'A':
            if qtde_litros <= 20:
                valor_total = qtde_litros * preco_alcool * 0.97
            else:
                valor_total = qtde_litros * preco_alcool * 0.95

        else:#elif tipo_combustivel.upper() == 'G':
            if qtde_litros <= 20:
                valor_total = qtde_litros * preco_gasolina * 0.96
            else:
                valor_total = qtde_litros * preco_gasolina * 0.94

        print('Tipo de combustível: {}'.format(tipo_combustivel.upper()))
        print('Litros: {}'.format(qtde_litros))
        print('Valor Total: R${:.2f}'.format(valor_total))

    else:
        print('Dados incorretos.')

else:
    print('Favor digitar os dados corretamente.')
# Out:
# Tipo de combustível: A
# Litros: 85.0
# Valor Total: R$274.55

# %% [markdown]
# #### 21. Uma fruteira está vendendo frutas com a seguinte tabela de preços:
# <pre>
#                       Até 5 Kg           Acima de 5 Kg
# Morango         R$ 2,50 por Kg          R$ 2,20 por Kg
# Maçã            R$ 1,80 por Kg          R$ 1,50 por Kg
# Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00, receberá ainda um desconto de 10% sobre este total. Escreva um algoritmo para ler a quantidade (em Kg) de morangos e a quantidade (em Kg) de maças adquiridas e escreva o valor a ser pago pelo cliente.
# </pre>

# %%
preco_morango1 = 2.5
preco_morango2 = 2.2
preco_maca1 = 1.8
preco_maca2 = 1.5

while True:
    try:
        peso_morango = float(input('Informe a quantidade de morango, em Kg: '))
        peso_maca = float(input('Informe a quantidade de maçã, em Kg: '))

        break
    except ValueError:
        print('Dados incorretos. Favor informar novamente.')

if peso_morango and peso_maca:
    if (peso_morango <= 5) and (peso_maca <= 5):
        preco_total = (peso_morango * preco_morango1) + (peso_maca * preco_maca1)
    elif (peso_morango <= 5) and (peso_maca > 5):
        preco_total = (peso_morango * preco_morango1) + (peso_maca * preco_maca2)
    elif (peso_morango > 5) and (peso_maca <= 5):
        preco_total = (peso_morango * preco_morango2) + (peso_maca * preco_maca1)
    elif (peso_morango > 5) and (peso_maca > 5):
        preco_total = (peso_morango * preco_morango2) + (peso_maca * preco_maca2)
    else:
        print('Dados incorretos.')

    #print(preco_total)

    peso_total = peso_morango + peso_maca
    if (peso_total > 8) or (preco_total > 25):
        preco_total *= 0.9

    print('Valor Total: {}'.format(preco_total))

else:
    print('Favor digitar os dados corretamente.')
# Out:
# Valor Total: 19.35

# %% [markdown]
# #### 22. O Hipermercado Tabajara está com uma promoção de carnes que é imperdível. Confira:
# <pre>
#                  Acima de 5 Kg           Até 5 Kg
# File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
# Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
# Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
#
# Para atender a todos os clientes, cada cliente poderá levar apenas um dos tipos de carne da promoção, porém, não há limites para a quantidade</br>
# de carne por cliente. Se compra for feita no cartão Tabajara, o cliente receberá, ainda, um desconto de 5% sobre o total da compra.</br>
# Escreva um programa que peça o tipo e a quantidade de carne comprada pelo usuário e gere um cupom fiscal, contendo as informações da compra: tipo e</br>
# quantidade de carne, preço total, tipo de pagamento, valor do desconto e valor a pagar.
# </pre>

# %%
preco_file1 = 5.8
preco_file2 = 4.9
preco_alcatra1 = 6.8
preco_alcatra2 = 5.9
preco_picanha1 = 7.8
preco_picanha2 = 6.9

while True:
    try:
        tipo_carne = str(input('Informe o tipo de carne (File/Alcatra/Picanha): '))
        qtde_carne = float(input('Informe a quantidade de carne, em Kg: '))
        cartao_tabajara = str(input('Pagamento com Cartão Tabajara (sim/nao)? '))

        break
    except ValueError:
        print('Dados incorretos. Favor informar novamente.')

if tipo_carne and qtde_carne and cartao_tabajara:
    if tipo_carne == 'file' or tipo_carne == 'alcatra' or tipo_carne == 'picanha':
        if tipo_carne.lower() == 'file':
            if qtde_carne <= 5:
                preco_kg = preco_file1
                preco_total = qtde_carne * preco_file1
            else:
                preco_kg = preco_file2
                preco_total = qtde_carne * preco_file2
        
        elif tipo_carne.lower() == 'alcatra':
            if qtde_carne <= 5:
                preco_kg = preco_alcatra1
                preco_total = qtde_carne * preco_alcatra1
            else:
                preco_kg = preco_alcatra2
                preco_total = qtde_carne * preco_alcatra2

        elif tipo_carne.lower() == 'picanha':
            if qtde_carne <= 5:
                preco_kg = preco_picanha1
                preco_total = qtde_carne * preco_picanha1
            else:
                preco_kg = preco_picanha2
                preco_total = qtde_carne * preco_picanha2
        
    else:
        print('Digite os dados corretamente.')

    if cartao_tabajara.lower() == 'sim' or cartao_tabajara.lower() == 'nao':
        if cartao_tabajara.lower() == 'sim':
            tipo_pagamento = 'Cartão Tabajara'
            desconto = preco_total * 0.05
            valor_a_pagar = preco_total * 0.95
        
        elif cartao_tabajara.lower() == 'nao':
            tipo_pagamento = 'Outros'
            valor_a_pagar = preco_total
        
        print('-------CUPOM FISCAL-------')
        print('Tipo de carne: {}. Quantidade: {}Kg'.format(tipo_carne, qtde_carne))
        print('Preco por Kg: R${:.2f}'.format(preco_kg))
        print('Preço total: R${:.2f}'.format(preco_total))
        print('Tipo de pagamento: {}'.format(tipo_pagamento))
        print('Valor do Desconto: R${:.2f}'.format(desconto))
        print('Valor a pagar: R${:.2f}'.format(valor_a_pagar))

    else:
        print('Dados incorretos. Tente novamente.')

else:
    print('Favor digitar os dados corretamente.')
# Out:
# -------CUPOM FISCAL-------
# Tipo de carne: picanha. Quantidade: 5.0Kg
# Preco por Kg: R$7.80
# Preço total: R$39.00
# Tipo de pagamento: Outros
# Valor do Desconto: R$1.95
# Valor a pagar: R$39.00

# %% [markdown]
# #### 23. Faça um Programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados</br>
# #### da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados e que</br>
# #### a tinta é vendida em latas de 18 litros, que custam R\\$ 80,00 ou em galões de 3,6 litros, que custam R\\$ 25,00.

# %%
area = float(input('Informe o tamanho da área a ser pintada em m²: '))
litros_tinta = area / 6

# %% [markdown]
# ##### Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações.
#
# Dica: lembre dos operadores // e % mostrados em exercícios anteriores<br>
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10.<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10.
#
# ##### 1. Comprar apenas latas de 18 litros: (apenas latas inteiras)

# %%
while True:
    try:
        area = float(input('Informe o tamanho da área a ser pintada em m²: '))
        litros_tinta = area / 6

        break
    except ValueError:
        print('Dados incorretos. Favor informar novamente.')

if litros_tinta:
    if litros_tinta % 18 > 0:
        qtde_latas = litros_tinta // 18 + 1

    else:
        qtde_latas = litros_tinta // 18
    valor_total = qtde_latas * 80

    print('Serão necessárias {} latas, custando R${} no total'.format(qtde_latas, valor_total))

else:
    print('Favor inserir novamente.')
# Out:
# Dados incorretos. Favor informar novamente.
# Dados incorretos. Favor informar novamente.
# Dados incorretos. Favor informar novamente.
# Dados incorretos. Favor informar novamente.
# Serão necessárias 1.0 latas, custando R$80.0 no total

# %% [markdown]
# ##### 2. Comprar apenas galões de 3,6 litros: (apenas galoes inteiros)

# %%
while True:
    try:
        area = float(input('Informe o tamanho da área a ser pintada em m²: '))

        break
    except ValueError:
        print('Dados incorretos. Favor informar novamente.')

if area:
    litros_tinta = area / 6
    if litros_tinta % 3.6 > 0:
        qtde_latas = litros_tinta // 3.6 + 1

    else:
        qtde_latas = litros_tinta // 3.6
    valor_total = qtde_latas * 25

    print('Serão necessárias {} latas, custando R${} no total'.format(qtde_latas, valor_total))

else:
    print('Favor inserir novamente.')
# Out:
# Serão necessárias 2.0 latas, custando R$50.0 no total

# %% [markdown]
# ##### 3. Misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias.

# %% [markdown]
# O custo da lata é 80/18 = 4,44 R$/L
#
# O custo do galão é 25/3,6 = 6,94 R$/L
#
# A lata é mais econômica, então todas as latas inteiras que pudermos usar devemos comprar em latas. Se ficar faltando alguma coisa para completar devemos avaliar se é melhor comprar latas ou galões. Exemplo:
#
# Se queremos comprar 90 litros. 5 latas dão exatamente 90 litros. Então devemos comprar tudo em latas.
#
# Se queremos comprar 95 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 5 litros faltantes precisamos de 2 galões que custam 50 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar 2 galões.
#
# Se queremos comprar 107 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 17 litros faltantes precisamos de 5 galões que custam 125 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar uma lata.
#
# 3 galões custam 75 reais, 4 galões custam 100 reais. Então, se for possível completar com até 3 galões escolhe-se galões. Qualquer quantidade maior que 3 galões, usa-se latas.
#
# Podemos ir ao exercício:

# %%
while True:
    try:
        area = float(input('Informe o tamanho da área a ser pintada em m²: '))

        break
    except ValueError:
        print('Dados incorretos. Favor informar novamente.')

if area:
    litros_tinta = area / 6

    # Folga de 10%
    litros_folga = litros_tinta * 1.1
    #galoes = 0

    # Latas inteiras
    latas = litros_folga // 18

    # Tinta faltante que não cabe em uma lata completa
    tinta_faltante = litros_folga - 18 * latas

    # Tinta faltante em galões
    if tinta_faltante > 0:
        if tinta_faltante % 3.6 > 0:
            galoes_faltantes = tinta_faltante // 3.6 + 1
        else:
            galoes_faltantes = tinta_faltante // 3.6
        if galoes_faltantes <= 3:
            galoes = galoes_faltantes
        else:
            galoes = 0
            latas = latas + 1

    preco = latas * 80 + galoes * 25
    print('São necessários {} latas e {} galões de tinta, ao valor total de R${}'.format(latas, galoes, preco))

else:
    print('Dados incorretos.')
# Out:
# São necessários 0.0 latas e 1.0 galões de tinta, ao valor total de R$25.0
